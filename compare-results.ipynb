# %% [markdown]
# # Compare BedSmells results

# %% [markdown]
# Make sure to run the benchmarks of the notebook `run-benchmarks` before running this notebook.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import json
import seaborn as sns
from collections import defaultdict

# %% [markdown]
# ## Preparation

# %% [markdown]
# Let's define a function to help us load the json results stored on the file system, generated by the `run-benchmarks` notebook

# %%
def load_results(directory: str, tests: list[str]):
    """
    Loads the results of benchmarks for each given provided test

    Args:
        directory(str): Path of results
        tests(str): The tests to load
    """
    results = {}
    if not os.path.exists(directory):
        return results
    
    for attack in os.listdir(directory):
        attack_dir = os.path.join(directory, attack, "tests")
        if not os.path.exists(attack_dir):
            continue
        
        results[attack] = {}
        for test in tests:
            test_file = next((f for f in os.listdir(attack_dir) if test in f), None)
            if test_file:
                with open(os.path.join(attack_dir, test_file), "r") as f:
                    parsed_json = json.load(f)
                    
                    if test == "CompleteTest":
                        results[attack] = parsed_json["CompleteTest"]
                    else:
                        results[attack][test] = parsed_json
    return results

# %% [markdown]
# Let's load the jsons

# %%
improved_dir = "results/CIC17_improved"
tests = ["CosineTest", "NearestNeighboursTest", "PortTest", "SingleFeatureEfficacyTest"]

improved_results = [
    load_results('results/CIC17_improved_first_run', ["CompleteTest"]),
    load_results('results/CIC17_improved_second_run', ["CompleteTest"]),
    load_results('results/CIC17_improved_third_run', ["CompleteTest"])
]

# %%
improved_results[0]['Port Scan']
# Out:
# {'CosineTest': {},
#  'MislabelPortsTest': {'MislabelPorts': 0, 'MislabelPortsPercent': 0.0},
#  'MislabelTest': 'Error!',
#  'SingleFeatureEfficacy': {'F1Scores': {'id': 1.0,
#    'Flow Duration': 1.0,
#    'Total Length of Bwd Packet': 1.0,
#    'Flow Bytes/s': 1.0,
#    'Flow IAT Mean': 1.0,
#    'Flow IAT Std': 1.0,
#    'Flow IAT Min': 1.0,
#    'Fwd IAT Total': 1.0,
#    'Fwd IAT Mean': 1.0,
#    'Fwd IAT Std': 1.0,
#    'Fwd IAT Max': 1.0,
#    'Fwd IAT Min': 1.0,
#    'Bwd IAT Total': 1.0,
#    'Bwd IAT Mean': 1.0,
#    'Bwd IAT Std': 1.0,
#    'Bwd IAT Min': 1.0,
#    'Fwd URG Flags': 1.0,
#    'Bwd URG Flags': 1.0,
#    'URG Flag Count': 1.0,
#    'ECE Flag Count': 1.0,
#    'Fwd Bytes/Bulk Avg': 1.0,
#    'Fwd Bulk Rate Avg': 1.0,
#    'Bwd Bytes/Bulk Avg': 1.0,
#    'Bwd Bulk Rate Avg': 1.0,
#    'Subflow Bwd Packets': 1.0,
#    'Active Mean': 1.0,
#    'Active Std': 1.0,
#    'Active Max': 1.0,
#    'Active Min': 1.0,
#    'Idle Mean': 1.0,
#    'Idle Std': 1.0,
#    'Idle Max': 1.0,
#    'Idle Min': 1.0,
#    'Total TCP Flow Time': 1.0,
#    'Flow IAT Max': 1.0,
#    'Bwd IAT Max': 1.0,
#    'Packet Length Variance': 1.0,
#    'ACK Flag Count': 1.0,
#    'CWR Flag Count': 1.0,
#    'Bwd Packet/Bulk Avg': 1.0,
#    'Flow Packets/s': 1.0,
#    'Bwd Packets/s': 1.0,
#    'Fwd Packets/s': 1.0,
#    'Bwd Init Win Bytes': 1.0,
#    'Fwd Packet Length Std': 1.0,
#    'Bwd Packet Length Std': 1.0,
#    'Total Length of Fwd Packet': 1.0,
#    'Total Bwd packets': 1.0,
#    'Total Fwd Packet': 1.0,
#    'Packet Length Std': 1.0,
#    'Packet Length Mean': 1.0,
#    'Bwd Segment Size Avg': 1.0,
#    'Bwd Packet Length Mean': 1.0,
#    'Average Packet Size': 1.0,
#    'Fwd Packet Length Max': 1.0,
#    'Subflow Fwd Packets': 1.0,
#    'Bwd PSH Flags': 1.0,
#    'PSH Flag Count': 1.0,
#    'Subflow Bwd Bytes': 1.0,
#    'Fwd RST Flags': 1.0,
#    'Bwd Packet Length Min': 1.0,
#    'Bwd RST Flags': 1.0,
#    'Bwd Packet Length Max': 1.0,
#    'Fwd Segment Size Avg': 1.0,
#    'Bwd Header Length': 1.0,
#    'Fwd Packet/Bulk Avg': 1.0,
#    'Packet Length Max': 1.0,
#    'Fwd Packet Length Mean': 1.0,
#    'Fwd Header Length': 1.0,
#    'RST Flag Count': 1.0,
#    'Fwd PSH Flags': 1.0,
#    'Subflow Fwd Bytes': 1.0,
#    'Fwd Packet Length Min': 1.0,
#    'Packet Length Min': 1.0,
#    'Fwd Act Data Pkts': 1.0,
#    'FWD Init Win Bytes': 1.0,
#    'FIN Flag Count': 1.0,
#    'SYN Flag Count': 1.0,
#    'Fwd Seg Size Min': 1.0,
#    'Protocol': 1.0,
#    'Down/Up Ratio': 1.0,
#    'ICMP Type': 1.0,
#    'ICMP Code': 1.0,
#    'Attempted Category': 1.0}}}

# %% [markdown]
# ## Heuristics

# %% [markdown]
# Let's now compare them for each metric shown in the paper [DataBadSmells](https://github.com/DataBadSmells/DataBadSmells)

# %%
def calculate_heuristics(test_results: dict) -> dict:
    """
    Extracts heuristic values (PDDC, TCC, HDFC, UGTC, WLC) from the given test results.
    
    Parameters:
        test_results (dict): Dictionary containing test results for a given attack class.

    Returns:
        dict: Dictionary with calculated heuristic values.
    """
    heuristics = {}
    
    # Extracting values from test results
    cosine_test = test_results.get('CosineTest', {})
    mislabel_ports_test = test_results.get('MislabelPortsTest', {})
    mislabel_test = test_results.get('MislabelTest', None)
    single_feature_efficacy = test_results.get('SingleFeatureEfficacy', {}).get('F1Scores', {})
    
    # PDDC: Poor Data Diversity (Largest Cluster Percentage)
    pddc = cosine_test.get('Largest Cluster Percentage', None)
    
    # TCC: Traffic Collapse (Percentage of flows with Cosine Similarity > 0.95)
    cutoff_percentages = cosine_test.get('Cutoff Percentages', {})
    tcc = max(cutoff_percentages.values(), default=None) if isinstance(cutoff_percentages, dict) else None
    
    # HDFC: Highly Dependent Features (Maximum F1-score from Single Feature Efficacy test)
    hdfc = max(single_feature_efficacy.values(), default=None) if single_feature_efficacy else None
    
    # UGTC: Unclear Ground Truth (Mislabel Ports Percentage)
    ugtc = mislabel_ports_test.get('MislabelPortsPercent', None)
    
    # WLC: Wrong Label Count (Mislabel Percentage or error flag)
    wlc = mislabel_test.get('Percentage', None) if isinstance(mislabel_test, dict) else None
    
    heuristics['PDDC'] = pddc
    heuristics['TCC'] = tcc
    heuristics['HDFC'] = hdfc
    heuristics['UGTC'] = ugtc
    heuristics['WLC'] = wlc
    
    return heuristics

# %% [markdown]
# For simplicity, we use the results defined in the paper of [DataBadSmells](https://github.com/DataBadSmells/DataBadSmells)

# %%
paper_reported_base_dataset_heuristics = {
    "Port Scan": {"PDDC": 0.99, "TCC": 0.99, "WLC": 0.0, "HDFC": 0.98, "UGTC": 0.0},
    "DoS Hulk": {"PDDC": 0.98, "TCC": 0.98, "WLC": 0.0, "HDFC": 1.0, "UGTC": 0.0},
    "FTP Patator": {"PDDC": 0.98, "TCC": 0.98, "WLC": 0.0, "HDFC": 0.99, "UGTC": 0.0},
    "SSH Patator": {"PDDC": 1.0, "TCC": 1.0, "WLC": 0.0, "HDFC": 0.98, "UGTC": 0.0},
    "DDoS": {"PDDC": 0.98, "TCC": 0.94, "WLC": 0.0, "HDFC": 0.99, "UGTC": 0.0},
    "Bot": {"PDDC": 0.98, "TCC": 1.0, "WLC": 0.01, "HDFC": 1.0, "UGTC": 0.0},
    "DoS slowloris": {"PDDC": 0.97, "TCC": 1.0, "WLC": 0.0, "HDFC": 0.98, "UGTC": 0.0},
    "DoS Slowhttptest": {"PDDC": 0.88, "TCC": 0.53, "WLC": 0.0, "HDFC": 0.96, "UGTC": 0.0},
    "DoS GoldenEye": {"PDDC": 0.95, "TCC": 0.68, "WLC": 0.0, "HDFC": 1.0, "UGTC": 0.0},
    "Infiltration": {"PDDC": 0.92, "TCC": 0.65, "WLC": 0.81, "HDFC": 0.75, "UGTC": 0.0},
    "Web Attack - Brute Force": {"PDDC": 0.99, "TCC": 0.93, "WLC": 0.06, "HDFC": 0.91, "UGTC": 0.0},
    "XSS": {"PDDC": 0.78, "TCC": 0.48, "WLC": 0.35, "HDFC": 0.93, "UGTC": 0.0},
    "Web Attack - Sql Injection": {"PDDC": None, "TCC": None, "WLC": 0.63, "HDFC": None, "UGTC": 0.0},
    "Heartbleed": {"PDDC": None, "TCC": None, "WLC": 0.18, "HDFC": None, "UGTC": 0.0},
}

# %% [markdown]
# ### Comparison

# %% [markdown]
# We can now show & compare the results obtained

# %%
metrics = ["PDDC", "TCC", "WLC", "HDFC"]
formatted_metrics = []

for metric in metrics:
    formatted_metrics.append(f"{metric} (base paper)")
    
    for i, _ in enumerate(improved_results):
        formatted_metrics.append(f"{metric} (improved #{i})")

# prepare results list with alternating base and improved values
data = []
attacks = list(improved_results[0].keys())

improved_heuristics = [{attack: calculate_heuristics(result[attack]) for attack in result} for result in improved_results]

for attack in attacks:
    row = [attack]
    for metric in metrics:
        row.append(paper_reported_base_dataset_heuristics[attack][metric])
        
        for h in improved_heuristics:
            if h[attack][metric]:
                row.append(f"{h[attack][metric]:.2f}")
            else:
                row.append("NaN")
    data.append(row)

df = pd.DataFrame(data, columns=["Attack"] + formatted_metrics)

df
# Out:
#                         Attack  PDDC (base paper) PDDC (improved #0)  \
# 0                  SSH Patator               1.00               0.51
# 1                     DoS Hulk               0.98               0.70
# 2                         DDoS               0.98               0.51
# 3                DoS slowloris               0.97                NaN
# 4                   Heartbleed                NaN                NaN
# 5             DoS Slowhttptest               0.88               0.57
# 6                    Port Scan               0.99                NaN
# 7                  FTP Patator               0.98               0.46
# 8                          Bot               0.98                NaN
# 9   Web Attack - Sql Injection                NaN                NaN
# 10                Infiltration               0.92               1.00
# 11    Web Attack - Brute Force               0.99                NaN
# 12               DoS GoldenEye               0.95               0.62
#
#    PDDC (improved #1) PDDC (improved #2)  TCC (base paper) TCC (improved #0)  \
# 0                0.51               0.50              1.00              0.95
# 1                0.71               0.70              0.98              0.78
# 2                0.51               0.50              0.94              0.48
# 3                 NaN                NaN              1.00               NaN
# 4                 NaN                NaN               NaN               NaN
# 5                0.56               0.58              0.53              0.68
# 6                 NaN                NaN              0.99               NaN
# 7                0.53               0.51              0.98              0.99
# 8                 NaN                NaN              1.00               NaN
# 9                 NaN                NaN               NaN               NaN
# 10               0.47               0.43              0.65              0.03
# 11                NaN               0.94              0.93               NaN
# 12               0.48               0.62              0.68              0.38
#
#    TCC (improved #1) TCC (improved #2)  WLC (base paper) WLC (improved #0)  \
# 0               0.97              0.97              0.00               NaN
# 1               0.74              0.76              0.00              0.00
# 2               0.47              0.46              0.00              0.00
# 3                NaN               NaN              0.00               NaN
# 4                NaN               NaN              0.18              1.00
# 5               0.70              0.68              0.00              1.00
# 6                NaN               NaN              0.00               NaN
# 7               0.99              0.98              0.00               NaN
# 8                NaN               NaN              0.01               NaN
# 9                NaN               NaN              0.63               NaN
# 10              0.36              0.19              0.81              1.00
# 11               NaN              0.86              0.06              1.00
# 12              0.46              0.38              0.00              1.00
#
#    WLC (improved #1) WLC (improved #2)  HDFC (base paper) HDFC (improved #0)  \
# 0                NaN               NaN               0.98               1.00
# 1               0.01              0.00               1.00               1.00
# 2               0.00              0.00               0.99               1.00
# 3                NaN               NaN               0.98               1.00
# 4               1.00              1.00                NaN               1.00
# 5               1.00              1.00               0.96               0.95
# 6                NaN               NaN               0.98               1.00
# 7                NaN               NaN               0.99               1.00
# 8                NaN               NaN               1.00               1.00
# 9                NaN               NaN                NaN               1.00
# 10              1.00              1.00               0.75               0.95
# 11              1.00              1.00               0.91               0.98
# 12              1.00              0.49               1.00               1.00
#
#    HDFC (improved #1) HDFC (improved #2)
# 0                1.00               1.00
# 1                1.00               1.00
# 2                1.00               1.00
# 3                1.00               1.00
# 4                1.00               1.00
# 5                0.95               0.95
# 6                1.00               1.00
# 7                1.00               1.00
# 8                1.00               1.00
# 9                1.00               1.00
# 10               0.95               0.95
# 11               0.98               0.98
# 12               1.00               1.00

# %%
# plot results
fig, axes = plt.subplots(len(metrics), 1, figsize=(12, 18))

for i, metric in enumerate(metrics):
    ax = axes[i]
    attack_labels = df["Attack"]
    
    base_paper_values = df[f"{metric} (base paper)"].astype(float)
    improved_values = [df[f"{metric} (improved #{j})"].astype(float) for j in range(len(improved_results))]

    width = 0.2
    x = np.arange(len(attack_labels))

    ax.bar(x - width, base_paper_values, width=width, label="Base Paper", color="gray")

    for j, values in enumerate(improved_values):
        ax.bar(x + (j * width), values, width=width, label=f"Improved #{j}")

    ax.set_xticks(x)
    ax.set_xticklabels(attack_labels, rotation=45, ha="right")
    ax.set_ylabel(metric)
    ax.set_title(f"Comparison of {metric} Across Attacks")
    ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Aggregate multiple runs & plot

# %% [markdown]
# Since we measured the heuristics multiple times, we get the mean and display them

# %%
metrics = ["PDDC", "TCC"]
formatted_metrics = []

for metric in metrics:
    formatted_metrics.append(f"{metric} (base paper)")
    formatted_metrics.append(f"{metric} (improved)")

# prepare results list with alternating base and improved values
data = []
attacks = list(improved_results[0].keys())

improved_heuristics = [{attack: calculate_heuristics(result[attack]) for attack in result} for result in improved_results]

# initialize a dictionary to store sum and count of values for computing mean
heuristics_sum = defaultdict(lambda: defaultdict(float))
heuristics_count = defaultdict(lambda: defaultdict(int))

# aggregate the values
for result in improved_heuristics:
    for attack, heuristics in result.items():
        for metric, value in heuristics.items():
            if value is not None:  # skip None values
                heuristics_sum[attack][metric] += value
                heuristics_count[attack][metric] += 1

# compute the mean
improved_heuristics_mean = {
    attack: {
        metric: (heuristics_sum[attack][metric] / heuristics_count[attack][metric])
        if heuristics_count[attack][metric] > 0 else None  # Preserve None if no valid values
        for metric in heuristics_sum[attack]
    }
    for attack in heuristics_sum
}

improved_heuristics_mean = dict(
    sorted(
        improved_heuristics_mean.items(),
        key=lambda item: (
            item[1].get('PDDC') if item[1].get('PDDC') is not None else -1,
            item[1].get('TCC') if item[1].get('TCC') is not None else -1
        ),
        reverse=True
    )
)

attacks = sorted(
    attacks,
    key=lambda attack: (
        improved_heuristics_mean.get(attack, {}).get("PDDC", -1),
        improved_heuristics_mean.get(attack, {}).get("TCC", -1)
    ),
    reverse=True
)

for attack in attacks:
    row = [attack]
    for metric in metrics:
        row.append(paper_reported_base_dataset_heuristics[attack].get(metric, "NaN"))  # Ensure key exists
        
        # Safely get the improved mean value
        mean_value = improved_heuristics_mean.get(attack, {}).get(metric, None)
        if mean_value is not None:
            row.append(f"{mean_value:.2f}")
        else:
            row.append("NaN")

    data.append(row)

df = pd.DataFrame(data, columns=["Attack"] + formatted_metrics)

df
# Out:
#                         Attack  PDDC (base paper) PDDC (improved)  \
# 0     Web Attack - Brute Force               0.99            0.94
# 1                     DoS Hulk               0.98            0.70
# 2                 Infiltration               0.92            0.63
# 3                DoS GoldenEye               0.95            0.57
# 4             DoS Slowhttptest               0.88            0.57
# 5                  SSH Patator               1.00            0.51
# 6                         DDoS               0.98            0.51
# 7                  FTP Patator               0.98            0.50
# 8                DoS slowloris               0.97             NaN
# 9                   Heartbleed                NaN             NaN
# 10                   Port Scan               0.99             NaN
# 11                         Bot               0.98             NaN
# 12  Web Attack - Sql Injection                NaN             NaN
#
#     TCC (base paper) TCC (improved)
# 0               0.93           0.86
# 1               0.98           0.76
# 2               0.65           0.20
# 3               0.68           0.41
# 4               0.53           0.69
# 5               1.00           0.97
# 6               0.94           0.47
# 7               0.98           0.99
# 8               1.00            NaN
# 9                NaN            NaN
# 10              0.99            NaN
# 11              1.00            NaN
# 12               NaN            NaN

# %%
# plot results
fig, axes = plt.subplots(len(metrics), 1, figsize=(12, 7))

for i, metric in enumerate(metrics):
    ax = axes[i]
    attack_labels = df["Attack"]
    
    base_paper_values = df[f"{metric} (base paper)"].astype(float)
    improved_values = [df[f"{metric} (improved)"].astype(float)]

    width = 0.3
    x = np.arange(len(attack_labels))

    ax.bar(x - width, base_paper_values, width=width, label="Original", color="gray")

    for j, values in enumerate(improved_values):
        ax.bar(x, values, width=width, label=f"Improved")

    ax.set_xticks(x)
    ax.yaxis.grid(True, linestyle="--", alpha=0.7)
    ax.set_xticklabels(attack_labels, rotation=45, ha="right")
    ax.set_ylabel(metric)
    ax.set_title(f"Comparison of {metric} Across Attacks")
    ax.legend()

plt.tight_layout()

plt.savefig("results/comparison.png")

plt.show()
